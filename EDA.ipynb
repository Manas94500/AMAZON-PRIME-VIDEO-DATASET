# %% [markdown]
# <a href="https://colab.research.google.com/github/Manas94500/AMAZON-PRIME-VIDEO-DATASET/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -Amazon Prime Video Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1**   - Manas Singh

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This exploratory analysis helped reveal key patterns across the
# Amazon Prime Video library. The platform largely prioritizes movies,
# with an expansion in titles after 2010. Top genres remain Drama,
# Comedy, and Thriller, reflecting mass audience preference. IMDb and
# TMDB scores reveal general positive engagement patterns. These
# insights can help Amazon optimize licensing investments, audience
# appeal, and content strategies across demographics.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# GitHub Link:- [https://github.com/Manas94500/AMAZON-PRIME-VIDEO-DATASET](https://github.com/Manas94500/AMAZON-PRIME-VIDEO-DATASET)

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This dataset was created to analyze all shows available on Amazon Prime Video, allowing us to extract valuable insights such as:
#
# Content Diversity: What genres and categories dominate the platform?
#
# Regional Availability: How does content distribution vary across different regions? (Note: The dataset description later clarifies the data is available in the United States.)
#
# Trends Over Time: How has Amazon Prime's content library evolved?
#
# IMDb Ratings & Popularity: What are the highest-rated or most popular shows on the platform?.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective is to provide actionable insights into the Amazon Prime Video content library that can guide strategic decision-making for various stakeholders.
#
# Goal: To uncover key trends that influence subscription growth, user engagement, and content investment strategies in the streaming industry.
#
# Stakeholder Value:
#
# Businesses/Amazon Prime: Informing content acquisition/production decisions (what genres/types to invest in) to maximize user satisfaction and growth.
#
# Content Creators: Understanding what kind of content (genres, popularity scores, historical trends) performs well to guide their pitches and production efforts.
#
# Data Analysts: Providing a structured analysis of the content landscape, including diversity, temporal trends, and performance metrics (IMDb/TMDB scores).

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

from google.colab import files
from IPython.display import display

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

print("Upload titles.csv")
files.upload()

print("Upload credits.csv")
files.upload()

titles = pd.read_csv("titles.csv")
credits = pd.read_csv("credits.csv")
# Out:
# Upload titles.csv
#      <input type="file" id="files-61faff2b-5542-4b09-bf5f-87186fab95a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61faff2b-5542-4b09-bf5f-87186fab95a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
display(titles.head())
display(credits.head())
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Titles Shape:", titles.shape)
print("Credits Shape:", credits.shape)
# Out:
# Titles Shape: (9871, 15)
# Credits Shape: (124235, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

print("Duplicate rows in TITLES:", titles.duplicated().sum())
print("Duplicate rows in CREDITS:", credits.duplicated().sum())
# Out:
# Duplicate rows in TITLES: 3
# Duplicate rows in CREDITS: 56

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

print(titles.isna().sum())
print(credits.isna().sum())
# Out:
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64
# person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(10,4))
sns.heatmap(titles.isna(), cbar=False)
plt.title("Missing Values Heatmap - TITLES")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset contains detailed information about Amazon Prime Video titles available in the United States, covering both movies and TV shows. It includes attributes such as release year, genre, runtime, certifications, IMDb ratings, TMDB popularity, and production regions. The dataset captures both content metadata and quality indicators, enabling exploration of content diversity, trends over time, and viewer reception. It also contains missing values in fields like IMDb scores, TMDB scores, and seasons, which need to be handled carefully before analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
titles.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
# Dataset Describe
titles.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9871.000000  9871.000000  1357.000000  8850.000000  8.840000e+03
# mean    2001.327221    85.973052     2.791452     5.976395  8.533614e+03
# std       25.810071    33.512466     4.148958     1.343842  4.592015e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1995.500000    65.000000     1.000000     5.100000  1.170000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.625000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.236250e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# count      9324.000000  7789.000000
# mean          6.910204     5.984247
# std          30.004098     1.517986
# min           0.000011     0.800000
# 25%           1.232000     5.100000
# 50%           2.536000     6.000000
# 75%           5.634000     6.900000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset includes variables related to:
#
# Content Identity - id, title
#
# Content Type - movie or TV show
#
# Description / Metadata - description, age certification, genres, runtime, seasons
#
# Time Attribute - release year
#
# Quality & Popularity Metrics - IMDb score, IMDb votes, TMDB score, popularity
#
# Production Side Attributes - production countries
#
# External Reference IDs - imdb_id
#
# Each variable helps in identifying descriptive, categorical, or numeric information required for analysis.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in titles.columns:
    print(col, "→", titles[col].nunique())
# Out:
# id → 9868
# title → 9737
# type → 2
# description → 9734
# release_year → 110
# age_certification → 11
# runtime → 207
# genres → 2028
# production_countries → 497
# seasons → 32
# imdb_id → 9201
# imdb_score → 86
# imdb_votes → 3650
# tmdb_popularity → 5325
# tmdb_score → 89

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

titles["age_certification"].fillna("Unknown", inplace=True)

# expand genres for later visualization
titles["genres"] = titles["genres"].astype(str)
# Out:
# /tmp/ipython-input-2366437068.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titles["age_certification"].fillna("Unknown", inplace=True)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **Cleaned the dataset by:**
#
# Checking and handling null/missing values
#
# Identifying critical missing fields (IMDb scores, votes, TMDB scores)
#
# Extracting individual genres using split + explode
#
# Detecting data inconsistencies in genre formatting
#
# Creating year-wise and genre-wise performance tables
#
# Filtering top-rated and lowest-rated titles
#
# Measuring correlations between quality & popularity
#
# **Key Insights Identified:**
#
# Movies dominate Amazon Prime over TV Shows.
#
# Average IMDb scores decreased between 2017-2021 but recovered in 2022.
#
# Highest-rated genres are Reality, Sport, Documentary & History.
#
# Genres are highly skewed—few dominate the platform.
#
# Titles with more votes usually have higher IMDb scores.
#
# Missing ratings can affect ranking accuracy.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 -Distribution of Content Type

# %%
plt.figure(figsize=(6,4))
titles["type"].value_counts().plot(kind="bar")
plt.title("Distribution of Content Type")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is ideal as it clearly compares the volume of Movies vs TV Shows side-by-side, making category differences easy to observe.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows which content format dominates the platform, highlighting which type is prioritized in the library.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight helps balance content acquisition; heavy dominance of one category may reduce audience diversity, while balancing both can improve customer engagement and reduce churn.

# %% [markdown]
# #### Chart - 2 -Release Trend Over Years

# %%
plt.figure(figsize=(10,4))
titles["release_year"].value_counts().sort_index().plot()
plt.title("Content Release Trend Over Years")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line plot effectively visualizes how the number of releases changes chronologically year-by-year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The dataset shows clear growth in the release volume in recent years, with certain peak periods visible.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# An increasing trend suggests content expansion and freshness, boosting attraction; a declining trend phase may signal reduced production and risk competitive loss.

# %% [markdown]
# #### Chart - 3-IMDb Score Distribution

# %%
plt.figure(figsize=(8,4))
sns.histplot(titles["imdb_score"], bins=30)
plt.title("IMDb Score Distribution")
plt.xlabel("IMDb Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is appropriate to display distribution patterns of continuous numeric values like IMDb ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most titles cluster around the mid–high score range, indicating acceptable to good quality content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Higher average score drives trust and platform credibility, while too many low-scored titles can negatively affect viewer perception and satisfaction.

# %% [markdown]
# #### Chart - 4- Top Genres

# %%
plt.figure(figsize=(10,4))
titles['genres'].str.split(',').explode().value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Genres")
plt.xlabel("Genre")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart allows direct comparison across genres and highlights the most represented categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A small group of genres dominate the platform, while niche genres are underrepresented.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Focusing on underserved but high-demand genres can expand market reach, while over-dependence on top genres limits diversity and weakens recommendation depth.

# %% [markdown]
# #### Chart - 5- Votes vs Score

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(data=titles, x="imdb_votes", y="imdb_score")
plt.title("Votes vs IMDb Score")
plt.xlabel("Votes")
plt.ylabel("Score")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is ideal for studying relationships between two continuous variables like votes and ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Higher-voted titles tend to have higher IMDb scores, showing a positive association between popularity and quality perception.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Promoting high-scoring and high-voted content can improve engagement quickly, while ignoring low-engagement high-score titles may be a lost growth opportunity.

# %% [markdown]
# #### Chart - 6 - Correlation Heatmap

# %%
plt.figure(figsize=(7,5))
sns.heatmap(titles[["imdb_score","imdb_votes","tmdb_popularity","tmdb_score"]].corr(), annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap visually summarizes correlation strengths between key numeric performance variables clearly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# IMDb votes and IMDb score show a noticeable relationship; TMDB popularity also correlates moderately with other variables.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding correlations ensures smarter success prediction using fewer variables—inefficient variable selection wastes budget, while correlation-driven decisions increase ROI.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the analysis, Amazon Prime should:
#
# Increase investment in top-rated genres (Reality/Documentary) to capitalize on proven viewer satisfaction.
#
# Improve quality consistency—especially based on weak-rating years.
#
# Balance catalog by increasing high-demand TV shows for better retention.
#
# Use high-rated, high-vote titles as marketing anchors.
#
# Expand niche genres to increase engagement diversity.
#
# Reduce low-performing titles or push them only into niche recommendation segments.
#
# This would strengthen content library depth, average title quality, and user retention.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis shows Amazon Prime’s catalog is heavily movie-focused, with specific genres and release periods standing out significantly. Content quality trends indicate fluctuating ratings over the years, but recent improvement suggests strategic progress. Genres like Reality, Documentary, and Sport perform best, and popular high-rated titles correlate with viewer attraction. Addressing missing ratings, improving catalog balance, and leveraging strong-performing segments can enhance both user satisfaction and business growth.
